# %% [markdown]
# **IMPORT MODULES**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# **LOAD THE DATASET**

# %%
df=pd.read_csv('/content/creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
df.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 14589  25808 -0.897475  0.963371  0.997351  0.329928  0.998766 -1.287190
# 14590  25809 -0.377066  0.984515  0.988848 -0.261443  0.563332  0.197124
# 14591  25810 -0.353184  0.311241  1.586426 -1.515835 -0.636334 -0.836015
# 14592  25810  0.827638 -0.539202  1.108173  1.532278 -0.950308  0.344304
# 14593  25810  0.998296  0.017032  0.461620  1.368208 -0.206188  0.052016
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 14589  0.713085  0.019353 -0.859152  ...  0.118559  0.159961 -0.234309
# 14590  0.489867  0.281753 -0.543286  ... -0.234987 -0.625894 -0.077312
# 14591  0.441214 -0.188933  1.218595  ...  0.049963  0.562606 -0.406689
# 14592 -0.467828  0.217786  0.858742  ...  0.047470  0.029105 -0.094593
# 14593  0.078446  0.075048 -0.062245  ...  0.003259  0.104344 -0.105513
#
#             V24       V25       V26       V27       V28  Amount  Class
# 14589  0.381128  0.193193 -0.511092  0.092647  0.150261    1.00    0.0
# 14590 -0.732204 -0.187063  0.128292  0.254469  0.076702    3.57    0.0
# 14591  0.494957  0.647956 -0.388286  0.159966  0.085009   24.95    0.0
# 14592  0.081273  0.271180 -0.377904  0.058095  0.059355  153.12    0.0
# 14593  0.248319  0.601054 -0.349948  0.028877  0.018695   65.00    0.0
#
# [5 rows x 31 columns]

# %%
# statistical info
df.describe()
# Out:
#                Time            V1            V2            V3            V4  \
# count  14595.000000  14595.000000  14595.000000  14595.000000  14595.000000
# mean   10792.032340     -0.235811      0.282011      0.836032      0.301450
# std     8186.839389      1.733249      1.400373      1.580148      1.496648
# min        0.000000    -27.670569    -34.607649    -24.667741     -5.172595
# 25%     3120.000000     -0.970401     -0.286943      0.398123     -0.625120
# 50%     9773.000000     -0.318075      0.250711      0.954471      0.224760
# 75%    18803.000000      1.162579      0.884715      1.597879      1.190561
# max    25812.000000      1.960497     10.819665      4.101716     11.927512
#
#                  V5            V6            V7            V8            V9  \
# count  14595.000000  14595.000000  14595.000000  14595.000000  14595.000000
# mean      -0.120104      0.127537     -0.156243     -0.013481      0.957911
# std        1.298133      1.323191      1.245872      1.261769      1.225911
# min      -32.092129    -23.496714    -26.548144    -23.632502     -7.175097
# 25%       -0.715794     -0.626659     -0.613068     -0.182259      0.236513
# 50%       -0.189655     -0.150116     -0.107044      0.017372      0.941664
# 75%        0.350648      0.506657      0.421533      0.265299      1.628393
# max       34.099309     21.393069     34.303177     11.580797     10.392889
#
#        ...           V21           V22           V23           V24  \
# count  ...  14595.000000  14594.000000  14594.000000  14594.000000
# mean   ...     -0.067762     -0.159037     -0.034454      0.012039
# std    ...      0.868016      0.621954      0.495935      0.587166
# min    ...    -11.468435     -8.593642    -19.254328     -2.512377
# 25%    ...     -0.272041     -0.552756     -0.172855     -0.339159
# 50%    ...     -0.131119     -0.123733     -0.044678      0.060417
# 75%    ...      0.020973      0.228997      0.071047      0.393153
# max    ...     22.614889      4.534454     13.876221      3.200201
#
#                 V25           V26           V27           V28        Amount  \
# count  14594.000000  14594.000000  14594.000000  14594.000000  14594.000000
# mean       0.117138      0.035759      0.013899      0.003274     64.152226
# std        0.429228      0.554141      0.398324      0.254091    177.229967
# min       -4.781606     -1.338556     -7.976100     -3.575312      0.000000
# 25%       -0.137046     -0.369495     -0.075588     -0.014270      5.490000
# 50%        0.156878     -0.034165     -0.000305      0.016602     15.910000
# 75%        0.393032      0.369525      0.098414      0.073482     52.927500
# max        5.525093      3.517346      8.254376      4.860769   7712.430000
#
#               Class
# count  14594.000000
# mean       0.004180
# std        0.064518
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 31 columns]

# %%
# datatype info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14595 entries, 0 to 14594
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    14595 non-null  int64
#  1   V1      14595 non-null  float64
#  2   V2      14595 non-null  float64
#  3   V3      14595 non-null  float64
#  4   V4      14595 non-null  float64
#  5   V5      14595 non-null  float64
#  6   V6      14595 non-null  float64
#  7   V7      14595 non-null  float64
#  8   V8      14595 non-null  float64
#  9   V9      14595 non-null  float64
#  10  V10     14595 non-null  float64
#  11  V11     14595 non-null  float64
#  12  V12     14595 non-null  float64
#  13  V13     14595 non-null  float64
#  14  V14     14595 non-null  float64
#  15  V15     14595 non-null  float64
#  16  V16     14595 non-null  float64
#  17  V17     14595 non-null  float64
#  18  V18     14595 non-null  float64
#  19  V19     14595 non-null  float64
#  20  V20     14595 non-null  float64
#  21  V21     14595 non-null  float64
#  22  V22     14594 non-null  float64
#  23  V23     14594 non-null  float64
#  24  V24     14594 non-null  float64
#  25  V25     14594 non-null  float64
#  26  V26     14594 non-null  float64
#  27  V27     14594 non-null  float64
#  28  V28     14594 non-null  float64
#  29  Amount  14594 non-null  float64
#  30  Class   14594 non-null  float64
# dtypes: float64(30), int64(1)
# memory usage: 3.5 MB

# %% [markdown]
# PREPROCESSING THE DATASET

# %%
# check for null values
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
print(df.isna())
# Out:
#         Time     V1     V2     V3     V4     V5     V6     V7     V8     V9  \
# 0      False  False  False  False  False  False  False  False  False  False
# 1      False  False  False  False  False  False  False  False  False  False
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False  False  False  False  False  False  False  False  False  False
# 4      False  False  False  False  False  False  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 14590  False  False  False  False  False  False  False  False  False  False
# 14591  False  False  False  False  False  False  False  False  False  False
# 14592  False  False  False  False  False  False  False  False  False  False
# 14593  False  False  False  False  False  False  False  False  False  False
# 14594  False  False  False  False  False  False  False  False  False  False
#
#        ...    V21    V22    V23    V24    V25    V26    V27    V28  Amount  \
# 0      ...  False  False  False  False  False  False  False  False   False
# 1      ...  False  False  False  False  False  False  False  False   False
# 2      ...  False  False  False  False  False  False  False  False   False
# 3      ...  False  False  False  False  False  False  False  False   False
# 4      ...  False  False  False  False  False  False  False  False   False
# ...    ...    ...    ...    ...    ...    ...    ...    ...    ...     ...
# 14590  ...  False  False  False  False  False  False  False  False   False
# 14591  ...  False  False  False  False  False  False  False  False   False
# 14592  ...  False  False  False  False  False  False  False  False   False
# 14593  ...  False  False  False  False  False  False  False  False   False
# 14594  ...  False   True   True   True   True   True   True   True    True
#
#        Class
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 14590  False
# 14591  False
# 14592  False
# 14593  False
# 14594   True
#
# [14595 rows x 31 columns]

# %%
df=df.dropna()

# %%
print(df)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 14589  25808 -0.897475  0.963371  0.997351  0.329928  0.998766 -1.287190
# 14590  25809 -0.377066  0.984515  0.988848 -0.261443  0.563332  0.197124
# 14591  25810 -0.353184  0.311241  1.586426 -1.515835 -0.636334 -0.836015
# 14592  25810  0.827638 -0.539202  1.108173  1.532278 -0.950308  0.344304
# 14593  25810  0.998296  0.017032  0.461620  1.368208 -0.206188  0.052016
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 0      0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474
# 1     -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288
# 2      0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412
# 3      0.237609  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321
# 4      0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458
# ...         ...       ...       ...  ...       ...       ...       ...
# 14589  0.713085  0.019353 -0.859152  ...  0.118559  0.159961 -0.234309
# 14590  0.489867  0.281753 -0.543286  ... -0.234987 -0.625894 -0.077312
# 14591  0.441214 -0.188933  1.218595  ...  0.049963  0.562606 -0.406689
# 14592 -0.467828  0.217786  0.858742  ...  0.047470  0.029105 -0.094593
# 14593  0.078446  0.075048 -0.062245  ...  0.003259  0.104344 -0.105513
#
#             V24       V25       V26       V27       V28  Amount  Class
# 0      0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62    0.0
# 1     -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69    0.0
# 2     -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3     -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50    0.0
# 4      0.141267 -0.206010  0.502292  0.219422  0.215153   69.99    0.0
# ...         ...       ...       ...       ...       ...     ...    ...
# 14589  0.381128  0.193193 -0.511092  0.092647  0.150261    1.00    0.0
# 14590 -0.732204 -0.187063  0.128292  0.254469  0.076702    3.57    0.0
# 14591  0.494957  0.647956 -0.388286  0.159966  0.085009   24.95    0.0
# 14592  0.081273  0.271180 -0.377904  0.058095  0.059355  153.12    0.0
# 14593  0.248319  0.601054 -0.349948  0.028877  0.018695   65.00    0.0
#
# [14594 rows x 31 columns]

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
df_temp = df.drop(columns=['Time', 'Amount', 'Class'], axis=1)

# create dist plots
fig, ax = plt.subplots(ncols=4, nrows=7, figsize=(20, 50))
index = 0
ax = ax.flatten()

for col in df_temp.columns:
    sns.distplot(df_temp[col], ax=ax[index])
    index += 1
plt.tight_layout(pad=0.5, w_pad=0.5, h_pad=5)

# %%
sns.distplot(df['Time'])
# Out:
# <Axes: xlabel='Time', ylabel='Density'>

# %%
sns.distplot(df['Amount'])
# Out:
# <Axes: xlabel='Amount', ylabel='Density'>

# %% [markdown]
# COORELATION MATRIX

# %%
corr = df.corr()
plt.figure(figsize=(30,40))
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# INPUT SPLIT

# %%
X = df.drop(columns=['Class'], axis=1)
y = df['Class']

# %% [markdown]
# STANDARD SCALING

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_scaler = sc.fit_transform(X)

# %%
x_scaler[-1]
# Out:
# array([ 1.83474092,  0.7120904 , -0.18922218, -0.23697297,  0.71279995,
#        -0.06631061, -0.05709091,  0.18838376,  0.07016703, -0.83225479,
#         0.25695427,  0.48248357,  1.98573484, -0.63841419, -0.46482271,
#        -0.69246533, -0.58213979, -0.27915796, -0.6953848 , -0.10705089,
#        -0.10927019,  0.08183369,  0.42348827, -0.14328799,  0.40242153,
#         1.12744611, -0.69606885,  0.03760345,  0.06069028,  0.00478364])

# %% [markdown]
# MODEL TRAINING

# %%
# train test split
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, f1_score
x_train, x_test, y_train, y_test = train_test_split(x_scaler, y, test_size=0.25, random_state=42, stratify=y)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
# training
model.fit(x_train, y_train)
# testing
y_pred = model.predict(x_test)
print(classification_report(y_test, y_pred))
print("F1 Score:",f1_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      3634
#          1.0       0.82      0.60      0.69        15
#
#     accuracy                           1.00      3649
#    macro avg       0.91      0.80      0.85      3649
# weighted avg       1.00      1.00      1.00      3649
#
# F1 Score: 0.6923076923076923

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
# training
model.fit(x_train, y_train)
# testing
y_pred = model.predict(x_test)
print(classification_report(y_test, y_pred))
print("F1 Score:",f1_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      3634
#          1.0       1.00      0.80      0.89        15
#
#     accuracy                           1.00      3649
#    macro avg       1.00      0.90      0.94      3649
# weighted avg       1.00      1.00      1.00      3649
#
# F1 Score: 0.888888888888889

# %%
from xgboost import XGBClassifier
model = XGBClassifier(n_jobs=-1)
# training
model.fit(x_train, y_train)
# testing
y_pred = model.predict(x_test)
print(classification_report(y_test, y_pred))
print("F1 Score:",f1_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      3634
#          1.0       1.00      0.80      0.89        15
#
#     accuracy                           1.00      3649
#    macro avg       1.00      0.90      0.94      3649
# weighted avg       1.00      1.00      1.00      3649
#
# F1 Score: 0.888888888888889

# %%
# hint - use combination of over sampling and under sampling
# balance the class with equal distribution
from imblearn.over_sampling import SMOTE
over_sample = SMOTE()
x_smote, y_smote = over_sample.fit_resample(x_train, y_train)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
# training
model.fit(x_smote, y_smote)
# testing
y_pred = model.predict(x_test)
print(classification_report(y_test, y_pred))
print("F1 Score:",f1_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      3634
#          1.0       0.38      0.73      0.50        15
#
#     accuracy                           0.99      3649
#    macro avg       0.69      0.86      0.75      3649
# weighted avg       1.00      0.99      0.99      3649
#
# F1 Score: 0.5

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_jobs=-1)
# training
model.fit(x_smote, y_smote)
# testing
y_pred = model.predict(x_test)
print(classification_report(y_test, y_pred))
print("F1 Score:",f1_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      3634
#          1.0       1.00      0.80      0.89        15
#
#     accuracy                           1.00      3649
#    macro avg       1.00      0.90      0.94      3649
# weighted avg       1.00      1.00      1.00      3649
#
# F1 Score: 0.888888888888889

# %%
from xgboost import XGBClassifier
model = XGBClassifier(n_jobs=-1)
# training
model.fit(x_smote, y_smote)
# testing
y_pred = model.predict(x_test)
print(classification_report(y_test, y_pred))
print("F1 Score:",f1_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      3634
#          1.0       0.86      0.80      0.83        15
#
#     accuracy                           1.00      3649
#    macro avg       0.93      0.90      0.91      3649
# weighted avg       1.00      1.00      1.00      3649
#
# F1 Score: 0.8275862068965518
